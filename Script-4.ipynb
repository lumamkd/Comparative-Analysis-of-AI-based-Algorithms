# %%
import os
import pandas as pd
import shutil
import time

def process_csv_files(csv_folder, image_folder, dest_folder):
    # Ensure the destination folder exists
    if not os.path.exists(dest_folder):
        os.makedirs(dest_folder)
    
    # Loop through all CSV files in the csv_folder
    for filename in os.listdir(csv_folder):
        if filename.endswith('.csv'):
            csv_path = os.path.join(csv_folder, filename)
            basename = os.path.splitext(filename)[0]  # Extract the basename of the CSV file
            # Path to the sub-folder corresponding to the basename
            image_subfolder = os.path.join(image_folder, basename)
            # Ensure the Positive Tiles sub-folder exists within the current sub-folder
            positive_tiles_folder = os.path.join(image_subfolder, 'Positive Tiles')
            if not os.path.exists(positive_tiles_folder):
                os.makedirs(positive_tiles_folder)
            
            # List to store names of positive files for the current CSV file
            positive_files = []

            try:
                df = pd.read_csv(csv_path)
                if 'Type' in df.columns and 'File' in df.columns:
                    # Filter the dataframe for positive entries
                    positive_df = df[df['Type'] == 'POSITIVE']
                    # Extend the positive_files list with the filenames
                    positive_files.extend(positive_df['File'].tolist())
                else:
                    print(f"Warning: 'Type' or 'File' column missing in {filename}")
            except Exception as e:
                print(f"Error reading {filename}: {e}")
                continue  # Skip to the next file in case of error

            # Remove duplicates from positive_files list
            positive_files = set(positive_files)

            # Move the images to the Positive Tiles folder
            for image_name in positive_files:
                image_path = os.path.join(image_subfolder, image_name)
                if os.path.exists(image_path):
                    shutil.move(image_path, os.path.join(positive_tiles_folder, image_name))
                else:
                    print(f"Warning: Image {image_name} not found in {image_subfolder}")

if __name__ == "__main__":
    # Define folder paths
    csv_folder = 'C:/Users/kapongo.lumamba/OneDrive - University of KwaZulu-Natal/0 MSc Computer Science/1 Models Testing/Result - svs_v2'
    image_folder = 'C:/Users/kapongo.lumamba/TB_Demo/WSI-SVS-Tiles_v2'
    dest_folder = 'C:/Users/kapongo.lumamba/TB_Demo/WSI-SVS-Tiles_v1/0 PosTiles'

    # Record the start time
    start_time = time.time()
    print(f"Process started at: {time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(start_time))}")

    # Call the function
    process_csv_files(csv_folder, image_folder, dest_folder)

# Simulate a process with sleep
# Replace this with your actual process code
#time.sleep(5)  # Simulate a 5-second process

    # Record the end time
    end_time = time.time()
    print(f"Process ended at: {time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(end_time))}")

    # Calculate and print the duration
    duration = end_time - start_time
    print(f"Duration: {duration:.2f} seconds")


#Basename Extraction: Added basename = os.path.splitext(filename)[0] to extract the base name of each CSV file without the .csv extension.
#Sub-folder Handling: Used the basename to access the corresponding sub-folder in image_folder.
#Positive Tiles Sub-folder: Created a Positive Tiles sub-folder within each corresponding image sub-folder.
#Clearing List: Reset the positive_files list after processing each CSV file.
#With these changes, the script will now properly handle the CSV files, collect positive image filenames, 
    #and move the corresponding images to their respective Positive Tiles sub-folder.
# Out:
# Process started at: 2024-08-22 21:18:33
# Process ended at: 2024-08-22 21:57:26
# Duration: 2333.56 seconds

# %%
### Explanation:
#1. **Libraries**:
   #- `os` is used for interacting with the file system (e.g., listing files, checking paths).
   #- `pandas` is used for reading and processing CSV files.
   #- `shutil` is used for moving files.

#2. **Function `process_csv_files`**:
   #- **csv_folder**: Directory containing the CSV files.
   #- **image_folder**: Directory containing the images.
   #- **dest_folder**: Directory where the positive images will be moved.

#3. **CSV Processing**:
   #- For each CSV file, it checks if the columns `Type` and `File` exist.
   #- Filters rows where `Type` is `POSITIVE` and adds the corresponding `File` names to `positive_files`.

#4. **Image Moving**:
   #- Checks if each image in `positive_files` exists in the `image_folder`.
   #- Moves each existing image to the `dest_folder`.

#5. **Duplicates**:
   #- Removes duplicates from the `positive_files` list to avoid processing the same image multiple times.

### Notes:
#- Replace `'path/to/csv/folder'`, `'path/to/image/folder'`, and `'path/to/Positive Tiles'` with actual paths.
#- Ensure that pandas is installed (`pip install pandas`) and that all necessary directories exist or can be created.

# %%
#1. **Read CSV Files**: Loop through each CSV file in a directory and check the column `Type` for the value `POSITIVE`.
#2. **Collect File Names**: For each positive entry in the CSV file, collect the corresponding value from the `File` column into a list.
#3. **Move Images**: Access a directory containing PNG images, and move those images whose names are in the collected list to a new directory called `Positive Tiles`.

import os
import pandas as pd
import shutil

def process_csv_files(csv_folder, image_folder, dest_folder):
    # Ensure the destination folder exists
    if not os.path.exists(dest_folder):
        os.makedirs(dest_folder)
    
    # List to store names of positive files
    positive_files = []

    # Loop through all CSV files in the csv_folder
    for filename in os.listdir(csv_folder):
        if filename.endswith('.csv'):
            csv_path = os.path.join(csv_folder, filename)
            try:
                df = pd.read_csv(csv_path)
                if 'Type' in df.columns and 'File' in df.columns:
                    # Filter the dataframe for positive entries
                    positive_df = df[df['Type'] == 'POSITIVE']
                    # Extend the positive_files list with the filenames
                    positive_files.extend(positive_df['File'].tolist())
                else:
                    print(f"Warning: 'Type' or 'File' column missing in {filename}")
            except Exception as e:
                print(f"Error reading {filename}: {e}")

    # Remove duplicates from positive_files list
    positive_files = set(positive_files)

    # Move the images to the destination folder
    for image_name in positive_files:
        image_path = os.path.join(image_folder, image_name)
        if os.path.exists(image_path):
            shutil.move(image_path, os.path.join(dest_folder, image_name))
        else:
            print(f"Warning: Image {image_name} not found in {image_folder}")

if __name__ == "__main__":
    # Define folder paths
    csv_folder = 'Z:/Admin/KAPONGO/0 MSc/WSI for Testing/Result - ndpi_v1'
    image_folder = 'Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1'
    dest_folder = 'Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1/0 PosTiles'
    
    # Call the function
    process_csv_files(csv_folder, image_folder, dest_folder)
# Out:
# Warning: Image SL06 D6-2_005_153.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-17896 S_005_030.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL08 A3-2_000_004.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D40-2_091_075.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_063_155.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-11346 C2_016_126.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 AB1-2_084_072.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-19655 D2_058_112.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-11346 C2_000_058.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-28285 E2_028_003.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL08 A4-2_071_100.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_057_077.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-17896 S_069_008.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-21444 T2_031_066.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL27-1_010_004.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-11346 C2_010_025.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D5-2_005_092.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 07-21114 E_013_110.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-11346 C2_010_056.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 AB1-2_069_003.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_100_044.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_043_069.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL27-1_016_082.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-11346 C2_076_124.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 07-21114 Q_076_007.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_096_143.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL12 A1-2_062_084.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-21269 B2_042_039.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_104_033.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 AB1-2_022_056.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_094_028.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 07-21114 P_073_118.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 AB1-2_010_081.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D40-2_070_099.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 G1-2_007_047.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL27-1_065_017.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D38-2_001_053.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-21444 T2_019_070.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 G1-2_059_130.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-17896 S_035_015.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 AB1-2_011_002.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_099_009.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_091_176.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL08 A1-2_076_086.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D36-2_040_024.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL27-1_078_043.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-17896 S_044_004.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL12 A1-2_057_002.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL27-1_019_087.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_033_064.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D40-2_093_070.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 G1-2_054_128.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-28285 E2_055_104.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 07-21114 P_008_060.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D40-2_088_002.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 07-21114 P_006_033.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_068_181.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-19655 D2_007_107.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL12 A1-2_018_072.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 G1-2_008_056.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL27-1_012_061.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 G1-2_019_133.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_096_053.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL08 A4-2_017_099.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 AB1-2_031_011.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-11346 C2_033_014.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-21444 T2_036_040.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_097_109.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_021_035.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 AB1-2_062_082.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 07-21114 E_001_063.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-19655 D2_065_111.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL08 A3-2_027_006.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 07-21114 S_094_019.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 AB1-2_068_085.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D38-2_003_037.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 AB1-2_045_087.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_102_122.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL12 A1-2_020_005.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-21269 B2_071_088.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL12 A4-2_095_060.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_099_159.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-11346 C2_035_129.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 AB1-2_014_002.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D40-2_092_077.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D5-2_052_055.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_043_102.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-11346 C2_037_128.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D36-2_007_121.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-19655 D2_015_031.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D36-2_085_041.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL08 A1-2_059_104.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_099_131.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL08 A1-2_097_107.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_066_013.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D40-2_049_000.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D36-2_088_052.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 AB1-2_008_081.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL08 A1-2_093_092.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D36-2_013_016.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_054_029.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-17896 S_058_007.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_070_156.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL12 A1-2_052_085.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D36-2_017_057.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_062_181.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_084_169.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-19655 D2_020_102.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 AB1-2_055_059.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL08 A3-2_082_001.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL08 A1-2_061_104.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_001_025.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 07-21114 P_015_122.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL27-1_010_064.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 07-21114 E_021_106.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 07-21114 S_058_024.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL27-1_069_002.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_104_121.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 07-21114 E_003_059.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_034_008.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 07-21114 E_004_084.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D38-2_007_088.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_097_093.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_043_153.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL08 A1-2_058_111.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-19655 D2_014_020.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-21444 T2_004_039.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 07-21114 S_086_065.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 AB1-2_067_092.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 AB1-2_089_074.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_005_063.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-21269 B2_063_005.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 AB1-2_000_078.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-21444 T2_070_054.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 AB1-2_045_057.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_026_022.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_019_051.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D38-2_087_005.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL12 A1-2_060_036.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-21269 B2_039_041.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 AB1-2_042_095.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D38-2_010_085.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL08 A1-2_027_044.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_061_175.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-11346 C2_031_015.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL08 A4-2_016_089.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-17896 S_017_041.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-21444 T2_012_066.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL27-1_016_076.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D36-2_059_024.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL12 A4-2_101_034.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL27-1_052_003.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 AB1-2_023_045.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 G1-2_050_134.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D5-2_007_110.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL08 A3-2_043_000.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-17896 S_007_031.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-19655 D2_088_062.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL08 A1-2_061_002.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D36-2_034_005.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-17896 S_021_058.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-28285 E2_090_003.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D40-2_093_094.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_014_122.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 G1-2_003_097.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL12 A1-2_034_012.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_099_180.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL08 A4-2_065_102.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 07-21114 S_006_059.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-17896 S_024_047.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 AB1-2_091_075.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL12 A4-2_102_068.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL27-1_002_043.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL08 A3-2_079_044.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D36-2_016_004.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 G1-2_005_067.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_033_032.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL27-1_025_104.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-17896 S_006_013.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 AB1-2_041_077.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 07-21114 Q_070_049.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-11346 C2_041_133.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-19655 D2_009_029.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 G1-2_008_032.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL08 A4-2_044_097.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL12 A4-2_082_027.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_072_157.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL12 A4-2_089_079.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 AB1-2_043_082.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-19655 D2_034_112.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-21269 B2_070_083.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL12 A4-2_103_018.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL08 A3-2_025_110.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_094_089.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_057_062.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 G1-2_064_014.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL27-1_002_064.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL08 A4-2_021_085.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL12 A4-2_099_059.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL08 A3-2_067_089.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL12 A1-2_051_090.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_070_165.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-17896 S_064_014.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL12 A4-2_104_034.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-11346 C2_009_021.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 07-21114 P_009_064.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL12 A4-2_038_042.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_054_156.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_094_115.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL08 A4-2_093_050.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_064_152.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 G1-2_069_130.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL08 A4-2_054_095.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 G1-2_001_095.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D36-2_009_019.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-11346 C2_079_091.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_018_028.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 G1-2_050_009.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D36-2_066_024.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-11346 C2_003_136.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-17896 S_026_054.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL27-1_072_048.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D40-2_026_003.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_024_050.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL08 A3-2_043_102.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 07-21114 S_088_063.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-19655 D2_011_112.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL27-1_079_076.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-17896 S_050_001.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL27-1_074_021.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL08 A4-2_074_103.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 07-21114 E_000_059.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 AB1-2_008_009.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_015_030.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_090_129.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D38-2_013_049.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-11346 C2_077_020.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL12 A4-2_101_048.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL12 A1-2_057_058.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D36-2_039_032.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL08 A3-2_081_030.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D38-2_087_023.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-17896 S_034_057.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-28285 E2_003_041.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL12 A4-2_006_064.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL27-1_075_071.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 07-21114 E_008_087.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D36-2_015_124.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_083_023.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL27-1_075_069.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D36-2_038_004.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL12 A4-2_097_077.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D5-2_006_098.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 AB1-2_027_057.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL27-1_082_028.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL27-1_073_030.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL08 A3-2_000_076.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D36-2_045_022.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_096_121.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-21269 B2_055_096.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL08 A3-2_075_059.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL12 A1-2_004_081.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D40-2_037_099.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-11346 C2_014_112.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 AB1-2_039_000.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-11346 C2_001_135.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_091_098.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-11346 C2_005_033.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-17896 S_070_032.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D36-2_010_012.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D38-2_011_085.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D36-2_009_060.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL27-1_062_018.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D36-2_083_033.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL27-1_069_104.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-17896 S_071_010.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-11346 C2_022_008.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D5-2_005_070.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL08 A3-2_062_001.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-17896 S_069_020.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-19655 D2_064_114.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-21444 T2_009_005.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL27-1_031_001.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 G1-2_071_099.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL08 A4-2_007_077.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 AB1-2_079_053.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL08 A4-2_077_101.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 AB1-2_001_074.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL27-1_080_080.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 AB1-2_026_042.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-17896 S_071_011.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D5-2_053_078.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 AB1-2_024_092.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_045_154.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL12 A1-2_043_079.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D36-2_080_037.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL27-1_081_020.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 07-21114 E_082_108.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL27-1_069_094.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D38-2_084_039.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D36-2_006_022.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_106_119.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 G1-2_000_067.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-17896 S_002_001.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL08 A1-2_009_019.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 AB1-2_000_010.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_088_127.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 G1-2_039_004.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-11346 C2_012_012.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-21269 B2_044_100.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-21444 T2_077_053.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_092_006.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 G1-2_001_085.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL08 A4-2_014_096.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-21444 T2_001_000.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 AB1-2_048_003.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 AB1-2_049_094.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-21269 B2_049_059.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_070_054.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_013_053.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL12 A4-2_097_078.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D36-2_080_045.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-11346 C2_000_021.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-11346 C2_077_025.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-11346 C2_005_025.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 G1-2_065_065.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL27-1_060_012.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-11346 C2_014_022.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL27-1_080_033.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-28285 E2_082_088.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL12 A1-2_007_000.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 G1-2_069_117.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-21444 T2_023_001.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-28285 E2_001_047.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL12 A1-2_033_037.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 07-21114 E_031_103.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-19655 D2_055_112.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-11346 C2_083_057.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D38-2_084_042.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL27-1_004_016.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL27-1_067_012.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-21444 T2_007_027.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL08 A3-2_037_077.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-17896 S_071_035.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D40-2_039_097.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL08 A4-2_086_003.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL27-1_068_020.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-21444 T2_061_054.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-19655 D2_009_100.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 AB1-2_061_076.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 AB1-2_086_077.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-11346 C2_080_124.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL12 A4-2_095_075.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-11346 C2_050_131.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL12 A4-2_014_083.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-21269 B2_059_098.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 G1-2_010_084.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL08 A1-2_099_002.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-21444 T2_060_071.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-21269 B2_008_065.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D36-2_027_003.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D36-2_043_008.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-28285 E2_089_024.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-28285 E2_001_019.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 AB1-2_053_092.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 AB1-2_059_064.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_106_084.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL08 A3-2_044_076.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 G1-2_020_137.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 AB1-2_084_083.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D5-2_004_083.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL27-1_005_010.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-11346 C2_071_109.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL27-1_078_083.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_034_114.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 G1-2_001_013.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL08 A4-2_044_002.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_005_032.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL27-1_075_046.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 AB1-2_092_076.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D36-2_062_035.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-21444 T2_005_078.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 07-21114 S_059_021.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D5-2_049_002.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_057_031.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_075_145.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-17896 S_073_022.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 G1-2_008_137.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D38-2_004_083.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-21269 B2_088_079.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-21444 T2_028_007.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-19655 D2_009_099.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_058_064.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL08 A1-2_061_000.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 07-21114 E_061_105.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 AB1-2_006_040.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-28285 E2_003_036.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL08 A1-2_028_068.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-17896 S_032_057.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 AB1-2_043_070.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 G1-2_009_002.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-11346 C2_015_013.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 07-21114 P_001_003.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-21444 T2_076_021.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_086_172.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_101_106.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-28285 E2_008_077.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL12 A4-2_091_008.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL27-1_070_030.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D5-2_049_017.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 07-21114 E_040_063.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D36-2_013_058.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-11346 C2_014_121.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL27-1_017_007.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 AB1-2_002_033.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-21269 B2_080_068.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 AB1-2_005_022.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D40-2_045_098.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL08 A1-2_066_112.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL12 A4-2_090_034.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-17896 S_058_049.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 AB1-2_079_012.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D40-2_091_074.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-21444 T2_051_059.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL08 A1-2_013_014.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D36-2_067_053.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-21269 B2_084_054.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D5-2_013_075.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-21269 B2_059_036.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL12 A4-2_095_076.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-11346 C2_021_125.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D36-2_042_021.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-17896 S_059_058.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-17896 S_011_061.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_005_116.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL08 A1-2_034_068.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 G1-2_036_134.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_104_162.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL27-1_005_036.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D38-2_027_086.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-11346 C2_012_000.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_051_179.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL08 A1-2_069_063.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 AB1-2_081_086.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL08 A3-2_083_111.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_022_122.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D36-2_086_036.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D36-2_084_039.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_085_110.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL08 A3-2_090_082.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 AB1-2_066_091.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 AB1-2_077_084.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL27-1_006_076.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL27-1_012_036.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_004_077.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# ...
# Warning: Image SL06 D5-2_013_120.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 G1-2_070_058.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 G1-2_029_120.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-28285 E2_020_103.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D5-2_043_088.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_094_105.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-28285 E2_005_100.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 G1-2_022_124.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-21444 T2_003_044.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_085_041.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL08 A1-2_031_062.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-17896 S_064_051.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-17896 S_035_003.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_036_058.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D40-2_050_002.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 G1-2_007_108.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL27-1_070_000.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL08 A3-2_073_110.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-19655 D2_087_007.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-21444 T2_039_000.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_088_126.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 G1-2_069_091.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_040_082.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_049_006.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 07-21114 Q_013_074.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-17896 S_037_043.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-28285 E2_051_105.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D5-2_053_026.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D36-2_024_023.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D5-2_008_083.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL12 A4-2_006_066.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_038_178.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D36-2_052_002.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D38-2_023_089.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 07-21114 E_088_062.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 AB1-2_011_008.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-11346 C2_024_016.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 AB1-2_092_065.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-11346 C2_016_015.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL12 A1-2_019_000.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-17896 S_070_010.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_096_070.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL27-1_012_052.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL08 A1-2_058_103.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_035_061.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 07-21114 Q_002_101.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_071_051.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL12 A1-2_038_009.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 G1-2_056_089.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL08 A3-2_025_107.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL08 A3-2_039_050.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL12 A4-2_052_057.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D5-2_021_116.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-19655 D2_077_109.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D36-2_039_025.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-21269 B2_061_001.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 07-21114 S_004_048.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D36-2_026_030.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D40-2_092_000.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D36-2_019_026.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-21269 B2_046_100.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_065_017.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-11346 C2_018_015.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D40-2_032_099.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D5-2_051_049.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 AB1-2_087_064.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_091_175.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-21444 T2_005_041.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 AB1-2_032_067.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-11346 C2_078_059.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-28285 E2_001_084.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_034_046.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-17896 S_055_058.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-17896 S_066_062.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_010_032.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL08 A1-2_015_014.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL08 A1-2_067_065.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_049_044.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 AB1-2_054_092.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 AB1-2_093_022.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 07-21114 E_005_059.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D36-2_064_046.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D36-2_083_021.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 G1-2_003_025.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 G1-2_063_051.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_014_021.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-21269 B2_035_071.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-21269 B2_081_060.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_057_015.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D40-2_088_103.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_086_160.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-11346 C2_006_090.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-21269 B2_012_063.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-21269 B2_082_005.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D36-2_086_030.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-21444 T2_071_036.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL08 A4-2_015_006.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D38-2_017_002.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_040_044.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-17896 S_039_061.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_055_180.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-28285 E2_000_035.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D40-2_078_101.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_099_118.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL27-1_010_053.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-21269 B2_086_034.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 07-21114 E_000_040.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL08 A3-2_070_015.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 G1-2_013_085.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-11346 C2_019_100.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL27-1_051_094.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D5-2_043_006.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL08 A3-2_019_110.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 07-21114 Q_019_107.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL12 A1-2_042_089.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-21444 T2_045_006.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D36-2_057_019.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 G1-2_007_121.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_033_111.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 G1-2_037_138.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 AB1-2_009_090.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D5-2_045_000.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-11346 C2_029_138.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-28285 E2_032_106.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D38-2_068_090.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_022_130.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 G1-2_052_104.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL08 A4-2_088_052.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 07-21114 E_003_036.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D38-2_049_003.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-11346 C2_079_014.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-11346 C2_080_017.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-21269 B2_034_034.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D36-2_018_030.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D40-2_073_000.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL12 A1-2_036_037.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-28285 E2_038_103.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL08 A3-2_039_041.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_083_181.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D40-2_093_071.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D5-2_039_009.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-11346 C2_008_017.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_099_054.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL27-1_035_103.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL08 A4-2_043_097.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 AB1-2_092_019.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 AB1-2_006_085.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 13-11346 C2_009_019.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL08 A4-2_012_002.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image 07-21114 S_008_009.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
# Warning: Image SL06 D6-2_103_156.png not found in Z:/Admin/KAPONGO/1 TB Model - Python/WSI-NDPI-Tiles_v1
